# %%
import pickle
import pandas as pd
from collections import Counter

# %%
with open('NYTArticles.pkl', 'rb') as f:
    headlines = pickle.load(f)

# %%
# df.to_csv('NYTHeadlines.csv')

# %%
df = pd.DataFrame(headlines, columns=['timestamp', 'headline', 'keywords'])

# %%
keyword_cnt = Counter()

# %%
for kw_list in df['keywords'].values:
    for keyword in kw_list:
        keyword_cnt[keyword] += 1

# %%
keyword_cnt.most_common(1000)
# Out:
# [('Trump, Donald J', 7595),
#  ('United States Politics and Government', 6836),
#  ('Books and Literature', 2321),
#  ('Movies', 2034),
#  ('Politics and Government', 1962),
#  ('Television', 1824),
#  ('New York City', 1670),
#  ('United States International Relations', 1484),
#  ('Republican Party', 1411),
#  ('Weddings and Engagements', 1350),
#  ('Art', 1331),
#  ('Real Estate and Housing (Residential)', 1253),
#  ('Baseball', 1223),
#  ('Theater', 1214),
#  ('Fashion and Apparel', 1210),
#  ('Deaths (Obituaries)', 1108),
#  ('News and News Media', 1101),
#  ('Women and Girls', 1063),
#  ('Immigration and Emigration', 1003),
#  ('Travel and Vacations', 996),
#  ('Senate', 991),
#  ('Health Insurance and Managed Care', 967),
#  ('Russia', 952),
#  ('China', 942),
#  ('Terrorism', 919),
#  ('United States Defense and Military Forces', 828),
#  ('Law and Legislation', 810),
#  ('United States', 789),
#  ('Computers and the Internet', 787),
#  ('Patient Protection and Affordable Care Act (2010)', 784),
#  ('House of Representatives', 759),
#  ('Demonstrations, Protests and Riots', 757),
#  ('Photography', 743),
#  ('Murders, Attempted Murders and Homicides', 733),
#  ('New York Times', 723),
#  ('Appointments and Executive Changes', 719),
#  ('Basketball', 718),
#  ('Social Media', 692),
#  ('Music', 683),
#  ('Colleges and Universities', 657),
#  ('Cooking and Cookbooks', 656),
#  ('Labor and Jobs', 655),
#  ('Refugees and Displaced Persons', 655),
#  ('Sexual Harassment', 650),
#  ('Blacks', 648),
#  ('Football', 642),
#  ('Russian Interference in 2016 US Elections and Ties to Trump Associates',
#   629),
#  ('North Korea', 613),
#  ('Discrimination', 586),
#  ('Pop and Rock Music', 584),
#  ('Democratic Party', 581),
#  ('Education (K-12)', 577),
#  ('Restaurants', 575),
#  ('Presidential Election of 2016', 540),
#  ('Dancing', 540),
#  ('Global Warming', 537),
#  ('Suits and Litigation (Civil)', 536),
#  ('Islamic State in Iraq and Syria (ISIS)', 524),
#  ('Obama, Barack', 517),
#  ('Sex Crimes', 514),
#  ('Soccer', 513),
#  ('Great Britain', 506),
#  ('Elections', 496),
#  ('Museums', 483),
#  ('Tennis', 477),
#  ('United States Economy', 476),
#  ('Crossword Puzzles', 457),
#  ('Mergers, Acquisitions and Divestitures', 454),
#  ('Actors and Actresses', 442),
#  ('Writing and Writers', 437),
#  ('Regulation and Deregulation of Industry', 428),
#  ('Documentary Films and Programs', 428),
#  ('Race and Ethnicity', 422),
#  ('Justice Department', 420),
#  ('Syria', 419),
#  ('Children and Childhood', 418),
#  ('France', 417),
#  ('Muslims and Islam', 414),
#  ('Hockey, Ice', 412),
#  ('Executive Orders and Memorandums', 406),
#  ('Banking and Financial Institutions', 404),
#  ('International Trade and World Market', 403),
#  ('Supreme Court (US)', 394),
#  ('New York Yankees', 391),
#  ('International Relations', 384),
#  ('Federal Bureau of Investigation', 384),
#  ('Federal Taxes (US)', 383),
#  ('Classical Music', 383),
#  ('Defense and Military Forces', 380),
#  ('Illegal Immigration', 376),
#  ('de Blasio, Bill', 365),
#  ('Shopping and Retail', 360),
#  ('New York State', 356),
#  ('Putin, Vladimir V', 355),
#  ('Manhattan (NYC)', 355),
#  ('London (England)', 348),
#  ('Nuclear Weapons', 343),
#  ('Police Brutality, Misconduct and Shootings', 343),
#  ('California', 336),
#  ('Canada', 331),
#  ('Golf', 328),
#  ('Human Rights and Human Rights Violations', 327),
#  ('Facebook Inc', 326),
#  ('Iran', 322),
#  ('Australia', 315),
#  ('Comey, James B', 314),
#  ('European Union', 310),
#  ('Mexico', 308),
#  ('Automobiles', 306),
#  ('Federal Budget (US)', 304),
#  ('New York Mets', 301),
#  ('Deaths (Fatalities)', 300),
#  ('Germany', 298),
#  ('Comedy and Humor', 291),
#  ('Homosexuality and Bisexuality', 288),
#  ('Opera', 286),
#  ('Sessions, Jefferson B III', 283),
#  ('Stocks and Bonds', 282),
#  ('Google Inc', 281),
#  ('Israel', 276),
#  ('Reading and Writing Skills (Education)', 270),
#  ('Corruption (Institutional)', 269),
#  ('Taxation', 269),
#  ('Hurricane Harvey (2017)', 269),
#  ('Recipes', 267),
#  ('Drug Abuse and Traffic', 267),
#  ('South Korea', 265),
#  ('Greenhouse Gas Emissions', 261),
#  ('vis-multimedia', 260),
#  ('Uber Technologies Inc', 258),
#  ('Philanthropy', 258),
#  ('vis-photo', 257),
#  ('New York Fashion Week', 257),
#  ('Embargoes and Sanctions', 255),
#  ('Cyberwarfare and Defense', 253),
#  ('Airlines and Airplanes', 253),
#  ('Basketball (College)', 253),
#  ('Parenting', 252),
#  ('Kim Jong-un', 251),
#  ('Video Recordings, Downloads and Streaming', 248),
#  ('United Nations', 248),
#  ('Cuomo, Andrew M', 247),
#  ('Amazon.com Inc', 246),
#  ('Tax Credits, Deductions and Exemptions', 246),
#  ('Japan', 245),
#  ('Charlottesville, Va, Violence (August, 2017)', 245),
#  ('Subways', 241),
#  ('India', 241),
#  ('Playoff Games', 240),
#  ('National Football League', 235),
#  ('Brooklyn (NYC)', 235),
#  ('Economic Conditions and Trends', 234),
#  ('Twitter', 233),
#  ('Mobile Applications', 232),
#  ('Europe', 232),
#  ("Women's Rights", 232),
#  ('Transgender and Transsexuals', 231),
#  ('Advertising and Marketing', 226),
#  ('Texas', 226),
#  ('Great Britain Withdrawal from EU (Brexit)', 225),
#  ('Research', 224),
#  ('Parties (Social)', 224),
#  ('Tillerson, Rex W', 224),
#  ('Hotels and Travel Lodgings', 222),
#  ('Decisions and Verdicts', 220),
#  ('Espionage and Intelligence Services', 218),
#  ('Saudi Arabia', 218),
#  ('Turkey', 217),
#  ('Ethics and Official Misconduct', 217),
#  ("Men's Fashion Week", 216),
#  ('Hurricanes and Tropical Storms', 215),
#  ('Fringe Groups and Movements', 215),
#  ('Afghanistan', 214),
#  ('Puerto Rico', 214),
#  ('Prices (Fares, Fees and Rates)', 213),
#  ('Drugs (Pharmaceuticals)', 213),
#  ('Poetry and Poets', 213),
#  ('Xi Jinping', 211),
#  ('New Jersey', 210),
#  ('Prisons and Prisoners', 209),
#  ('Apple Inc', 206),
#  ('State Legislatures', 206),
#  ('Families and Family Life', 205),
#  ('Netflix Inc', 203),
#  ('War Crimes, Genocide and Crimes Against Humanity', 203),
#  ('Corporate Taxes', 202),
#  ('New York Knicks', 201),
#  ('Renting and Leasing (Real Estate)', 200),
#  ('Frauds and Swindling', 200),
#  ('Jews and Judaism', 198),
#  ('Police Department (NYC)', 197),
#  ('Moore, Roy S', 197),
#  ('Conflicts of Interest', 195),
#  ('Washington (DC)', 193),
#  ('Police', 193),
#  ('Clinton, Hillary Rodham', 193),
#  ('Los Angeles (Calif)', 190),
#  ('Iraq', 189),
#  ('Transit Systems', 189),
#  ('Bannon, Stephen K', 189),
#  ('Historic Buildings and Sites', 188),
#  ('Medicine and Health', 187),
#  ('Floods', 187),
#  ('Freedom of Speech and Expression', 187),
#  ('Rap and Hip-Hop', 186),
#  ('Houston (Tex)', 184),
#  ('Macron, Emmanuel (1977- )', 184),
#  ('Environmental Protection Agency', 183),
#  ('Wages and Salaries', 182),
#  ('Environment', 181),
#  ('May, Theresa M', 180),
#  ('Weinstein, Harvey', 180),
#  ('State Department', 179),
#  ('Fox News Channel', 179),
#  ('Elections, Senate', 179),
#  ('Sports Injuries', 177),
#  ('Gun Control', 177),
#  ('Podcasts', 176),
#  ('Dating and Relationships', 176),
#  ('Mental Health and Disorders', 176),
#  ('Alabama', 175),
#  ('Paris Fashion Week', 175),
#  ('Palestinians', 174),
#  ('Space and Astronomy', 174),
#  ('Academy Awards (Oscars)', 172),
#  ('Holocaust and the Nazi Era', 171),
#  ('Roman Catholic Church', 170),
#  ('Inaugurations', 169),
#  ('Factories and Manufacturing', 168),
#  ('Income Tax', 168),
#  ('Oil (Petroleum) and Gasoline', 168),
#  ('Monuments and Memorials (Structures)', 167),
#  ('Newspapers', 166),
#  ('Child Abuse and Neglect', 166),
#  ('Web-Original Programming', 165),
#  ('Hurricane Irma (2017)', 165),
#  ('McConnell, Mitch', 164),
#  ('Ryan, Paul D Jr', 164),
#  ('Missiles and Missile Defense Systems', 164),
#  ('Medicaid', 163),
#  ('Kushner, Jared', 162),
#  ('Flynn, Michael T', 162),
#  ('Hurricane Maria (2017)', 162),
#  ('Defense Department', 161),
#  ('Architecture', 161),
#  ('Infrastructure (Public Works)', 159),
#  ('Food', 159),
#  ('Colbert, Stephen', 159),
#  ('Metropolitan Transportation Authority', 158),
#  ('Vietnam War', 158),
#  ('Real Estate (Commercial)', 157),
#  ('Workplace Environment', 156),
#  ('Elderly', 155),
#  ('Mueller, Robert S III', 155),
#  ('Bribery and Kickbacks', 154),
#  ('Spain', 153),
#  ('Agriculture and Farming', 152),
#  ('Paris (France)', 152),
#  ('Football (College)', 151),
#  ('Cyberattacks and Hackers', 151),
#  ('United Nations Framework Convention on Climate Change', 151),
#  ('Car Services and Livery Cabs', 151),
#  ('Gorsuch, Neil M', 150),
#  ('Jazz', 149),
#  ('Civilian Casualties', 148),
#  ('Legislatures and Parliaments', 146),
#  ('Homeland Security Department', 146),
#  ('Referendums', 146),
#  ('Merkel, Angela', 145),
#  ('Computer Security', 145),
#  ('Abortion', 145),
#  ('Florida', 145),
#  ('Coaches and Managers', 144),
#  ('Bronx (NYC)', 144),
#  ('Erdogan, Recep Tayyip', 144),
#  ('Pregnancy and Childbirth', 143),
#  ('Elections, Mayors', 143),
#  ('Assad, Bashar al-', 143),
#  ('Psychology and Psychologists', 142),
#  ('Auctions', 141),
#  ('Exercise', 141),
#  ('Interior Design and Furnishings', 141),
#  ('Classified Information and State Secrets', 141),
#  ('Whites', 139),
#  ('Culture (Arts)', 139),
#  ('Courts and the Judiciary', 138),
#  ('Smartphones', 137),
#  ('Las Vegas, Nev, Shooting (October, 2017)', 137),
#  ('Federal Reserve System', 136),
#  ('Diplomatic Service, Embassies and Consulates', 136),
#  ('Budgets and Budgeting', 136),
#  ('Rumors and Misinformation', 136),
#  ('Marriages', 135),
#  ('Personal Finances', 135),
#  ('Driverless and Semiautonomous Vehicles', 135),
#  ('Italy', 134),
#  ('Awards, Decorations and Honors', 133),
#  ('Afghanistan War (2001- )', 133),
#  ('Brazil', 132),
#  ('Company Reports', 132),
#  ('Chicago (Ill)', 131),
#  ('Venezuela', 130),
#  ('Bars and Nightclubs', 129),
#  ('Start-ups', 129),
#  ('Presidents and Presidency (US)', 128),
#  ('Taliban', 127),
#  ('Campaign Finance', 127),
#  ('English Language', 127),
#  ('Dogs', 126),
#  ('DeVos, Elizabeth (1958- )', 126),
#  ('World War II (1939-45)', 125),
#  ('States (US)', 125),
#  ('Traffic Accidents and Safety', 125),
#  ('Le Pen, Marine', 125),
#  ('Late Show with Stephen Colbert (TV Program)', 125),
#  ('Men and Boys', 124),
#  ('E-Commerce', 124),
#  ('Special Prosecutors (Independent Counsel)', 124),
#  ('Trump, Ivanka', 123),
#  ('Hate Crimes', 123),
#  ('Fires and Firefighters', 122),
#  ('Diet and Nutrition', 121),
#  ('Hospitals', 121),
#  ('Polls and Public Opinion', 121),
#  ('Wildfires', 121),
#  ('Civil Rights and Liberties', 120),
#  ('Philippines', 120),
#  ('Nuclear Tests', 119),
#  ('Consumer Protection', 119),
#  ('Conservatism (US Politics)', 119),
#  ('Legal Profession', 118),
#  ('Design', 116),
#  ('Sculpture', 116),
#  ('Firearms', 116),
#  ('Metropolitan Opera', 115),
#  ('Voting and Voters', 115),
#  ('Myanmar', 114),
#  ('Artificial Intelligence', 114),
#  ('National Basketball Assn', 114),
#  ('Pain-Relieving Drugs', 114),
#  ('Deportation', 113),
#  ('Pruitt, Scott', 113),
#  ('Fallon, Jimmy', 113),
#  ('Kimmel, Jimmy', 113),
#  ('Microsoft Corp', 112),
#  ('Privacy', 111),
#  ('Africa', 111),
#  ('Trump, Donald J Jr', 111),
#  ('Elections, House of Representatives', 110),
#  ('Central Intelligence Agency', 110),
#  ('Income Inequality', 108),
#  ('Metropolitan Museum of Art', 108),
#  ('Assaults', 108),
#  ('Spicer, Sean M (1971- )', 108),
#  ('Visas', 108),
#  ('Houston Astros', 108),
#  ('Charlottesville (Va)', 108),
#  ('Immigration and Customs Enforcement (US)', 107),
#  ('Christians and Christianity', 107),
#  ('Deferred Action for Childhood Arrivals', 107),
#  ('Weather', 106),
#  ('Wines', 106),
#  ('Home Box Office', 106),
#  ('Golden State Warriors', 106),
#  ('Online Advertising', 106),
#  ('Vietnam', 106),
#  ('Egypt', 105),
#  ('Pence, Mike', 105),
#  ('Accidents and Safety', 105),
#  ('Credit and Debt', 105),
#  ('Yemen', 105),
#  ('Collectors and Collections', 104),
#  ('Interest Rates', 104),
#  ('Anti-Semitism', 104),
#  ('Cleveland Cavaliers', 103),
#  ('Magazines', 103),
#  ('Pakistan', 103),
#  ('United States Open (Tennis)', 103),
#  ('Rohingya (Ethnic Group)', 102),
#  ('London Fashion Week', 100),
#  ('Venture Capital', 100),
#  ('Organized Labor', 100),
#  ('Meyers, Seth', 100),
#  ('Catalonia (Spain)', 100),
#  ('Capital Punishment', 99),
#  ('Doping (Sports)', 99),
#  ('Disabilities', 99),
#  ('Airports', 99),
#  ('Brain', 99),
#  ('Middle East and Africa Migrant Crisis', 99),
#  ('Same-Sex Marriage, Civil Unions and Domestic Partnerships', 99),
#  ('Communist Party of China', 98),
#  ('North American Free Trade Agreement', 98),
#  ('Biological and Chemical Warfare', 98),
#  ('Careers and Professions', 97),
#  ('New York Rangers', 97),
#  ('McCain, John', 97),
#  ('Genetics and Heredity', 97),
#  ('Bicycles and Bicycling', 97),
#  ('Immigration Detention', 97),
#  ('Noah, Trevor (1984- )', 97),
#  ('Netanyahu, Benjamin', 96),
#  ('Kelly, John F (1950- )', 96),
#  ('Manafort, Paul J', 96),
#  ('Delays (Transportation)', 95),
#  ('Customs, Etiquette and Manners', 95),
#  ('Youth', 95),
#  ("O'Reilly, Bill", 95),
#  ('Duterte, Rodrigo', 95),
#  ('Las Vegas (Nev)', 95),
#  ('Middle East', 94),
#  ('North Atlantic Treaty Organization', 94),
#  ('Political Prisoners', 93),
#  ('Restoration and Renovation', 93),
#  ('Cuba', 93),
#  ('Foreign Workers', 93),
#  ('Crime and Criminals', 92),
#  ('Retirement', 92),
#  ('Virginia', 92),
#  ('Coal', 92),
#  ('Upper West Side (Manhattan, NY)', 91),
#  ('NCAA Basketball Championships (Men)', 91),
#  ('Freedom of the Press', 91),
#  ('Maduro, Nicolas', 91),
#  ('Boston Red Sox', 91),
#  ('New York Times Neediest Cases Fund', 90),
#  ('Endangered and Extinct Species', 90),
#  ('Air Pollution', 90),
#  ('Censorship', 90),
#  ('Bombs and Explosives', 90),
#  ('Birth Control and Family Planning', 90),
#  ('Midterm Elections (2018)', 90),
#  ('Mattis, James N', 89),
#  ('National Parks, Monuments and Seashores', 89),
#  ('Shutdowns (Institutional)', 89),
#  ('Kalanick, Travis', 89),
#  ('Elections, Governors', 88),
#  ('Hispanic-Americans', 88),
#  ('Poverty', 88),
#  ('High Net Worth Individuals', 88),
#  ('Teenagers and Adolescence', 88),
#  ('Los Angeles Dodgers', 88),
#  ('Walt Disney Company', 87),
#  ('Student Loans', 87),
#  ('Chefs', 87),
#  ('The Tonight Show (TV Program)', 87),
#  ('Civil War (US) (1861-65)', 87),
#  ('Trades (Sports)', 87),
#  ('Veterans', 86),
#  ('Jerusalem (Israel)', 86),
#  ('Draft and Recruitment (Sports)', 86),
#  ('Francis', 86),
#  ('Hedge Funds', 86),
#  ('Homeless Persons', 85),
#  ('Archives and Records', 85),
#  ('Foreign Investments', 85),
#  ('Flowers and Plants', 85),
#  ('Commuting', 85),
#  ('Science and Technology', 85),
#  ('Senate Committee on Intelligence', 85),
#  ('Consumer Financial Protection Bureau', 84),
#  ('Water', 84),
#  ('Hiring and Promotion', 84),
#  ('Evacuations and Evacuees', 84),
#  ('Muslim Americans', 83),
#  ('Alternative and Renewable Energy', 83),
#  ('Cosmetics and Toiletries', 83),
#  ('Celebrities', 83),
#  ('Kidnapping and Hostages', 83),
#  ('Fuel Emissions (Transportation)', 83),
#  ('Mnuchin, Steven T', 83),
#  ('Love (Emotion)', 83),
#  ('Initial Public Offerings', 82),
#  ('Automobile Racing', 82),
#  ('Voter Registration and Requirements', 82),
#  ('National Aeronautics and Space Administration', 82),
#  ('Education Department (US)', 82),
#  ('Speeches and Statements', 82),
#  ('Constitution (US)', 81),
#  ('Late Night with Seth Meyers (TV Program)', 81),
#  ('Lobbying and Lobbyists', 81),
#  ('21st Century Fox', 81),
#  ('Ukraine', 80),
#  ('Area Planning and Renewal', 80),
#  ('Doctors', 80),
#  ('Milan Fashion Week', 80),
#  ('Weight', 80),
#  ('Major League Baseball', 80),
#  ('Heart', 80),
#  ('Queens (NYC)', 79),
#  ('Gender', 79),
#  ('Chicago Cubs', 79),
#  ('Oceans and Seas', 79),
#  ('The Daily Show with Trevor Noah (TV Program)', 79),
#  ('Antitrust Laws and Competition Issues', 78),
#  ('Native Americans', 78),
#  ('Robots and Robotics', 78),
#  ('Slavery (Historical)', 78),
#  ('Hong Kong', 78),
#  ('Silicon Valley (Calif)', 78),
#  ('Animal Abuse, Rights and Welfare', 78),
#  ('Mosul (Iraq)', 78),
#  ('World Series', 77),
#  ('Water Pollution', 77),
#  ('Carbon Dioxide', 77),
#  ('Minorities', 77),
#  ('Olympic Games', 77),
#  ('Trump Organization', 77),
#  ('Medicare', 77),
#  ('Treasury Department', 77),
#  ('New England Patriots', 77),
#  ('Assassinations and Attempted Assassinations', 76),
#  ('American Civil Liberties Union', 76),
#  ('Robberies and Thefts', 76),
#  ('CNN', 76),
#  ('Harlem (Manhattan, NY)', 76),
#  ('Athletics and Sports', 75),
#  ('Death and Dying', 75),
#  ('Urban Areas', 75),
#  ('Archaeology and Anthropology', 75),
#  ('Far East, South and Southeast Asia and Pacific Areas', 75),
#  ('Georgia', 75),
#  ('Trump, Melania', 75),
#  ('Border Barriers', 75),
#  ('Roads and Traffic', 74),
#  ('Anxiety and Stress', 74),
#  ('Game of Thrones (TV Program)', 74),
#  ('Snap Inc', 74),
#  ('Humanitarian Aid', 74),
#  ('Netherlands', 74),
#  ('Upper East Side (Manhattan, NY)', 73),
#  ('Layoffs and Job Reductions', 73),
#  ('England', 73),
#  ('Unemployment', 73),
#  ('Philosophy', 73),
#  ('Hazardous and Toxic Substances', 73),
#  ('Federal Communications Commission', 73),
#  ('Eclipses', 73),
#  ('Budget Travel', 72),
#  ('Bakeries and Baked Products', 72),
#  ('Dodd-Frank Wall Street Reform and Consumer Protection Act (2010)', 72),
#  ('Federer, Roger', 72),
#  ('Religion and Belief', 71),
#  ('Kurds', 71),
#  ('Conservative Party (Great Britain)', 71),
#  ('Suicides and Suicide Attempts', 71),
#  ('Civil Rights Movement (1954-68)', 71),
#  ('USSR (Former Soviet Union)', 71),
#  ('Disasters and Emergencies', 71),
#  ('Wimbledon Tennis Tournament', 71),
#  ('Cancer', 70),
#  ('Fines (Penalties)', 70),
#  ('Cold War Era', 70),
#  ('Franken, Al', 70),
#  ('Moon Jae-in', 70),
#  ('National Anthems', 69),
#  ('Conservation of Resources', 68),
#  ('Hair', 68),
#  ('Indonesia', 68),
#  ('Conway, Kellyanne', 68),
#  ('Boards of Directors', 68),
#  ('Lincoln Center for the Performing Arts', 68),
#  ('Jones, Doug (1954- )', 68),
#  ('YouTube.com', 67),
#  ('Book Trade and Publishing', 67),
#  ('Bush, George W', 67),
#  ('Anthony, Carmelo', 67),
#  ('Somalia', 67),
#  ('Detainees', 66),
#  ('Impeachment', 66),
#  ('General Motors', 66),
#  ('Surveillance of Citizens by Government', 66),
#  ('World War I (1914-18)', 66),
#  ('New York Philharmonic', 66),
#  ('Super Bowl', 66),
#  ('San Francisco (Calif)', 66),
#  ('Nadal, Rafael', 66),
#  ('New Orleans (La)', 66),
#  ('Teachers and School Employees', 66),
#  ('Manchester Arena Bombing (May, 2017)', 66),
#  ('Affordable Housing', 65),
#  ('Torture', 65),
#  ('Obesity', 65),
#  ('Health and Human Services Department', 65),
#  ('Funerals and Memorials', 65),
#  ('Vaccination and Immunization', 65),
#  ('Poland', 65),
#  ('Land Use Policies', 65),
#  ('Workplace Hazards and Violations', 65),
#  ('Mines and Mining', 65),
#  ('Abe, Shinzo', 65),
#  ('Marijuana', 64),
#  ('Yellen, Janet L', 64),
#  ('Stadiums and Arenas', 64),
#  ('Christie, Christopher J', 64),
#  ('New York City Ballet', 64),
#  ('Trudeau, Justin', 64),
#  ('Citizenship and Naturalization', 64),
#  ('Cosby, Bill', 64),
#  ('Comic Books and Strips', 64),
#  ('Mohammed bin Salman (1985- )', 64),
#  ('Thanksgiving Day', 64),
#  ('Beijing (China)', 63),
#  ('Private and Sectarian Schools', 63),
#  ('Securities and Exchange Commission', 63),
#  ('Midtown Area (Manhattan, NY)', 63),
#  ('Electric and Hybrid Vehicles', 63),
#  ('Building (Construction)', 63),
#  ('Attacks on Police', 63),
#  ('International Olympic Committee', 63),
#  ('United States Navy', 63),
#  ('Food and Drug Administration', 63),
#  ('Kenya', 63),
#  ('Scaramucci, Anthony', 62),
#  ('Instagram Inc', 62),
#  ('Bangladesh', 62),
#  ('Entrepreneurship', 62),
#  ('Cameras', 62),
#  ('Haley, Nikki R', 62),
#  ('Boxing', 62),
#  ('Sutherland Springs, Tex, Shooting (2017)', 62),
#  ('Schumer, Charles E', 61),
#  ('Customs and Border Protection (US)', 61),
#  ('National Broadcasting Co', 61),
#  ('Railroads', 61),
#  ('Computer and Video Games', 61),
#  ('Pensions and Retirement Plans', 61),
#  ('Clinton, Bill', 61),
#  ('Asylum, Right of', 61),
#  ('Volkswagen AG', 61),
#  ('Rescues', 61),
#  ('Federal Emergency Management Agency', 61),
#  ('Earthquakes', 61),
#  ('Australian Open (Tennis)', 61),
#  ('Museum of Modern Art', 61),
#  ('Judge, Aaron (1992- )', 61),
#  ('Secession and Independence Movements', 61),
#  ('Birds', 60),
#  ('Rural Areas', 60),
#  ('Language and Languages', 60),
#  ('Running', 60),
#  ('Wiretapping and Other Eavesdropping Devices and Methods', 60),
#  ('Ethics (Personal)', 60),
#  ('Greece', 60),
#  ('Securities and Commodities Violations', 60),
#  ('Social Conditions and Trends', 60),
#  ('Cleveland Indians', 59),
#  ('Smoking and Tobacco', 59),
#  ('National Front (France)', 59),
#  ('Lower East Side (Manhattan, NY)', 59),
#  ('Arms Control and Limitation and Disarmament', 59),
#  ('Swimming', 59),
#  ('Pets', 59),
#  ('Software', 59),
#  ('Sex', 59),
#  ('Carnegie Hall', 59),
#  ('Congressional Budget Office', 59),
#  ('Net Neutrality', 59),
#  ('Wireless Communications', 58),
#  ('Shoes and Boots', 58),
#  ('Attorneys General', 58),
#  ('Congo, Democratic Republic of (Congo-Kinshasa)', 58),
#  ('Bridges and Tunnels', 58),
#  ('Nobel Prizes', 58),
#  ('Executives and Management (Theory)', 58),
#  ('Fish and Other Marine Life', 58),
#  ('Animals', 58),
#  ("Coups D'Etat and Attempted Coups D'Etat", 58),
#  ('Price, Thomas E (1954- )', 58),
#  ('Constitutions', 58),
#  ('Power Failures and Blackouts', 57),
#  ('Furniture', 57),
#  ('North Carolina', 57),
#  ('Maritime Accidents and Safety', 57),
#  ('Ireland', 57),
#  ('Al Qaeda', 57),
#  ('Aviation Accidents, Safety and Disasters', 57),
#  ('Goldman Sachs Group Inc', 57),
#  ('Parks and Other Recreation Areas', 57),
#  ('Luxury Goods and Services', 57),
#  ('Harvard University', 57),
#  ('Grammy Awards', 57),
#  ('Corden, James (1978- )', 57),
#  ('UEFA Champions League (Soccer)', 57),
#  ('Qatar', 57),
#  ('Yoga', 56),
#  ('Nigeria', 56),
#  ('Inflation (Economics)', 56),
#  ('Public Theater', 56),
#  ('National Collegiate Athletic Assn', 56),
#  ('Royal Families', 56),
#  ('Moscow (Russia)', 56),
#  ('Airport Security', 56),
#  ('Security Council (UN)', 56),
#  ('Chelsea (Manhattan, NY)', 56),
#  ('Saturday Night Live (TV Program)', 56),
#  ('National Security Agency', 56),
#  ('Wells Fargo & Company', 56),
#  ('Israeli Settlements', 56),
#  ('Breitbart News Network LLC', 55),
#  ('AT&T Inc', 55),
#  ('Addiction (Psychology)', 55),
#  ('News', 55),
#  ('Miami (Fla)', 55),
#  ('Zimbabwe', 55),
#  ('Jewels and Jewelry', 55),
#  ('Detroit (Mich)', 55),
#  ('Waste Materials and Disposal', 55),
#  ('Brooklyn Academy of Music', 55),
#  ('Cats', 55),
#  ('Protectionism (Trade)', 55),
#  ('Mortgages', 55),
#  ('Models (Professional)', 55),
#  ('Afghanistan War (2001-14)', 54),
#  ('United Airlines', 54),
#  ('Electric Light and Power', 54),
#  ('Ford Motor Co', 54),
#  ('Track and Field', 54),
#  ('Internal Revenue Service', 54),
#  ('College Athletics', 54),
#  ('Human Trafficking', 54),
#  ("Sotheby's", 54),
#  ('Surgery and Surgeons', 54),
#  ('Corporations', 54),
#  ('Epidemics', 54),
#  ('iPhone', 54),
#  ('South Africa', 54),
#  ('Admissions Standards', 53),
#  ('Greenwich Village (Manhattan, NY)', 53),
#  ('Sanders, Bernard', 53),
#  ('Meditation', 53),
#  ('First Ladies (US)', 53),
#  ('Pittsburgh Penguins', 53),
#  ('Bathrooms and Toilets', 53),
#  ('International Federation of Association Football (FIFA)', 53),
#  ('Boston Celtics', 53),
#  ('Planned Parenthood Federation of America', 53),
#  ('Age, Chronological', 53),
#  ('New York Jets', 52),
#  ('New York Giants', 52),
#  ('Aung San Suu Kyi', 52),
#  ('CBS Corporation', 52),
#  ('Concussions', 52),
#  ('Staten Island (NYC)', 52),
#  ('Liberalism (US Politics)', 52),
#  ('Sweden', 52),
#  ('Executive Compensation', 52),
#  ('ABC Inc', 52),
#  ('Audio Recordings, Downloads and Streaming', 52),
#  ('Kaepernick, Colin', 52),
#  ('Park Geun-hye', 51),
#  ('Knowles, Beyonce', 51),
#  ('Alphabet Inc', 51),
#  ('Dallas Cowboys', 51),
#  ('James, LeBron', 51),
#  ('Small Business', 51),
#  ('Sydney (Australia)', 51),
#  ('Shareholder Rights and Activism', 51),
#  ('Couture Fashion Week', 51),
#  ('Pennsylvania Station (Manhattan, NY)', 51),
#  ('United States National Anthem Protests (2016- )', 51),
#  ('Musk, Elon', 50),
#  ('Melbourne (Australia)', 50),
#  ('Equifax Inc', 50),
#  ('Telephones and Telecommunications', 50),
#  ('National Rifle Assn', 50),
#  ('Border Patrol (US)', 50),
#  ('Atlanta (Ga)', 50),
#  ("Alzheimer's Disease", 50),
#  ("Christie's", 50),
#  ('Miami Marlins', 50),
#  ('Long Island (NY)', 50),
#  ('Tony Awards (Theater Awards)', 50),
#  ('Federal Aid (US)', 50),
#  ('Ailes, Roger E', 50),
#  ('McMaster, H R', 50),
#  ('Washington Nationals', 50),
#  ('Skin', 49),
#  ('E-Mail', 49),
#  ('Golden Globes (Awards)', 49),
#  ('Reality Television', 49),
#  ('Nixon, Richard Milhous', 49),
#  ('Cartoons and Cartoonists', 49),
#  ('English Premier League', 49),
#  ('World Cup (Soccer)', 49),
#  ('Turnbull, Malcolm (1954- )', 49),
#  ('Boko Haram', 49),
#  ('Political Advertising', 49),
#  ('Parades', 49),
#  ('Williams, Venus', 49),
#  ('Flake, Jeffrey L', 49),
#  ('Corker, Robert Phillips Jr', 49),
#  ('Manhattan, NY, Attack (October, 2017)', 49),
#  ('Babies and Infants', 48),
#  ('Kansas', 48),
#  ('American Ballet Theater', 48),
#  ('Customs (Tariff)', 48),
#  ('Virtual Reality (Computers)', 48),
#  ('Arkansas', 48),
#  ('Mexico City (Mexico)', 48),
#  ('Depression (Mental)', 48),
#  ('Sleep', 48),
#  ('Porzingis, Kristaps (1995- )', 48),
#  ('Education', 48),
#  ('Labour Party (Great Britain)', 48),
#  ('Neo Nazi Groups', 48),
#  ('Philadelphia (Pa)', 48),
#  ('Olympic Games (2018)', 48),
#  ('Emmy Awards', 48),
#  ('East Village (Manhattan, NY)', 48),
#  ('Amtrak', 48),
#  ('Domestic Violence', 48),
#  ('Argentina', 48),
#  ('French Open (Tennis)', 48),
#  ('#MeToo Movement', 48),
#  ('Cellular Telephones', 47),
#  ('Supermarkets and Grocery Stores', 47),
#  ('Amnesties, Commutations and Pardons', 47),
#  ('Smuggling', 47),
#  ('Rouhani, Hassan', 47),
#  ('Berlin (Germany)', 47),
#  ('Solar Energy', 47),
#  ('Seattle (Wash)', 47),
#  ("O'Brien, Conan", 47),
#  ('Hawaii', 47),
#  ('Zuckerberg, Mark E', 47),
#  ('Dresses', 47),
#  ('Bankruptcies', 47),
#  ('Mosques', 47),
#  ('Group of Twenty', 47),
#  ('Grenfell Tower Fire (June, 2017)', 47),
#  ('Automobile Safety Features and Defects', 46),
#  ('Colorado', 46),
#  ('Shakespeare, William', 46),
#  ('Libraries and Librarians', 46),
#  ('Contests and Prizes', 46),
#  ('Guantanamo Bay Naval Base (Cuba)', 46),
#  ('Bitcoin (Currency)', 46),
#  ('Interior Department', 46),
#  ('Private Equity', 46),
#  ('Gardens and Gardening', 46),
#  ('ESPN', 46),
#  ('Louis Vuitton', 46),
#  ('Priebus, Reince R', 46),
#  ('Tesla Motors Inc', 46),
#  ('Freedom of Religion', 46),
#  ('World Baseball Classic', 46),
#  ('Organized Crime', 45),
#  ('Nonprofit Organizations', 45),
#  ('Therapy and Rehabilitation', 45),
#  ('United States Marine Corps', 45),
#  ('Nuclear Energy', 45),
#  ('City Council (NYC)', 45),
#  ('Park Slope (Brooklyn, NY)', 45),
#  ('False Arrests, Convictions and Imprisonments', 45),
#  ('Jackson, Phil (1945- )', 45),
#  ('Indigenous People', 45),
#  ('Ratings (Audience Measurement)', 45),
#  ('Mayors', 45),
#  ('University of California, Berkeley', 45),
#  ('Murdoch, Rupert', 45),
#  ('Hezbollah', 45),
#  ('September 11 (2001)', 44),
#  ('Modi, Narendra', 44),
#  ('Arizona', 44),
#  ('Buses', 44),
#  ('Customer Relations', 44),
#  ('Brooklyn Nets', 44),
#  ('Alaska', 44),
#  ('Bezos, Jeffrey P', 44),
#  ('Productivity', 44),
#  ('Centers for Disease Control and Prevention', 44),
#  ('Mugabe, Robert', 44),
#  ('Redistricting and Reapportionment', 44),
#  ('Warren, Elizabeth', 44),
#  ('Longevity', 44),
#  ('Relocation of Business', 44),
#  ('Taxicabs and Taxicab Drivers', 44),
#  ('New York Islanders', 44),
#  ('European Commission', 44),
#  ('Libya', 44),
#  ('Gambling', 44),
#  ('Missing Persons', 44),
#  ('Ohio', 44),
#  ('Guggenheim, Solomon R, Museum', 44),
#  ('Wisconsin', 44),
#  ('New Jersey Transit', 44),
#  ('Puigdemont, Carles (1962- )', 44),
#  ('La La Land (Movie)', 43),
#  ('Mar-a-Lago (Palm Beach, Fla)', 43),
#  ('Horse Racing', 43),
#  ('West Bank', 43),
#  ('Gangs', 43),
#  ('Cable Television', 43),
#  ('Pena Nieto, Enrique', 43),
#  ('Connecticut', 43),
#  ('Waymo', 43),
#  ('Kabul (Afghanistan)', 43),
#  ('Tests (Medical)', 43),
#  ('Sailboats and Sailing', 43),
#  ('Malaysia', 43),
#  ('SoHo (Manhattan, NY)', 43),
#  ('Barcelona (Spain)', 43),
#  ('Cyberharassment', 42),
#  ('Billboard (Magazine)', 42),
#  ('Propaganda', 42),
#  ('Johnson, Lyndon Baines', 42),
#  ('JPMorgan Chase & Company', 42),
#  ('Democratic National Committee', 42),
#  ('WikiLeaks', 42),
#  ('Financial Aid (Education)', 42),
#  ('Apologies', 42),
#  ('Singapore', 42),
#  ('Central Park (Manhattan, NY)', 42),
#  ('Segregation and Desegregation', 42),
#  ('Watches and Clocks', 42),
#  ('Windows (Operating System)', 42),
#  ('Caribbean Area', 42),
#  ('Charter Schools', 42),
#  ('Times Square and 42nd Street (Manhattan, NY)', 42),
#  ("United States Men's National Soccer Team", 42),
#  ('California Today', 42),
#  ('Congressional Baseball Team Shooting (June, 2017)', 42),
#  ('Diabetes', 41),
#  ('Foreign Aid', 41),
#  ('Baltimore (Md)', 41),
#  ('Moonlight (Movie)', 41),
#  ('Shortages', 41),
#  ('Balenciaga (Fashion Label)', 41),
#  ('Maine', 41),
#  ('Innovation', 41),
#  ('Senate Committee on the Judiciary', 41),
#  ('Rome (Italy)', 41),
#  ('Cohn, Gary D', 41),
#  ('Atlanta Falcons', 41),
#  ('Couture (Fashion)', 41),
#  ('Sisi, Abdel Fattah el-', 41),
#  ('National Security Council', 41),
#  ('Computer Chips', 41),
#  ('Elder Care', 41),
#  ('Walmart Stores Inc', 41),
#  ('United States Army', 41),
#  ('Rajoy, Mariano', 41),
#  ('Jimmy Kimmel Live (TV Program)', 41),
#  ('NBA Championship', 40),
#  ('Evangelical Movement', 40),
#  ('Gucci', 40),
#  ('Mutual Funds', 40),
#  ('Evolution (Biology)', 40),
#  ('Portugal', 40),
#  ('New Yorker', 40),
#  ('Arts and Antiquities Looting', 40),
#  ('Paleontology', 40),
#  ('National Debt (US)', 40),
#  ('First Amendment (US Constitution)', 40),
#  ('Colombia', 40),
#  ('Acquired Immune Deficiency Syndrome', 40),
#  ('Palestinian Authority', 40),
#  ('Trans-Pacific Partnership', 40),
#  ('Nursing Homes', 40),
#  ('School Shootings and Armed Attacks', 40),
#  ('Third World and Developing Countries', 40),
#  ('Lebanon', 40),
#  ('Graham, Lindsey', 40),
#  ('House Committee on Intelligence', 40),
#  ('Paddock, Stephen C (1953-2017)', 40),
#  ('Economics (Theory and Philosophy)', 39),
#  ('Public Broadcasting Service', 39),
#  ('New Zealand', 39),
#  ('Letters', 39),
#  ('Snow and Snowstorms', 39),
#  ('Millennial Generation', 39),
#  ('Local Government', 39),
#  ('Boycotts', 39),
#  ('Swift, Taylor', 39),
#  ('Forests and Forestry', 39),
#  ('Moon', 39),
#  ('Radio', 39),
#  ('Hunting and Trapping', 39),
#  ('Whistle-Blowers', 39),
#  ('Debates (Political)', 39),
#  ('Christian Dior SA', 39),
#  ('Lee, Robert E', 39),
#  ('Kennedy, John Fitzgerald', 39),
#  ('Buildings (Structures)', 39),
#  ('Delivery Services', 39),
#  ('Tax Shelters', 39),
#  ('Girardi, Joe', 39),
#  ('Rikers Island Prison Complex', 39),
#  ('Saipov, Sayfullo', 39),
#  ('Houston Rockets', 38),
#  ('Samsung Group', 38),
#  ('Williams, Serena', 38),
#  ('Drones (Pilotless Planes)', 38),
#  ('Railroad Accidents and Safety', 38),
#  ('Cocktails and Mixed Drinks', 38),
#  ('Forensic Science', 38),
#  ('Twin Peaks (TV Program)', 38),
#  ('Trump Tower (Manhattan, NY)', 38),
#  ('National Hockey League', 38)]

# %%
top_x = 1000

top_keys_decomp = {}

for key_pair in keyword_cnt.most_common(top_x):
    key = key_pair[0]
    decomp_keys = key.replace(',', '').replace('(', '').replace(')', '').split(' ')
    for sub_key in decomp_keys:
        if sub_key in top_keys_decomp:
            top_keys_decomp[sub_key] += key_pair[1]
        else:
            top_keys_decomp[sub_key] = key_pair[1]

# del top_keys_decomp['']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-7177df28b640> in <module>()
#       9         top_keys_decomp.add(sub_key)
#      10
# ---> 11 del top_keys_decomp['']
#
# TypeError: 'set' object does not support item deletion

# %%
top_keys_decomp
# Out:
# {'',
#  'Walt',
#  'ABC',
#  'Base',
#  'Information',
#  'Trafficking',
#  'Rates',
#  'Boko',
#  'Pop',
#  'Mining',
#  'vis-photo',
#  'the',
#  'Seth',
#  'Aviation',
#  'Plans',
#  'Audio',
#  'Bill',
#  'Directors',
#  'Pakistan',
#  'Iran',
#  'Open',
#  'Francis',
#  'on',
#  'Television',
#  'Budgets',
#  'Corden',
#  'Planes',
#  'Dogs',
#  'South',
#  'Entrepreneurship',
#  'Airplanes',
#  'Stadiums',
#  'UN',
#  'Labour',
#  'House',
#  'Swindling',
#  'Conan',
#  'Diplomatic',
#  'Guantanamo',
#  'Alaska',
#  'Valley',
#  'Ties',
#  'Union',
#  'Generation',
#  'Universities',
#  'Mnuchin',
#  'Etiquette',
#  'Village',
#  'Stores',
#  'Intelligence',
#  'Trade',
#  'Soccer',
#  'Bridges',
#  'Anti-Semitism',
#  'Mich',
#  'Abuse',
#  'Agreement',
#  'vis-multimedia',
#  'Pregnancy',
#  'Belief',
#  'Republican',
#  'Premier',
#  'Jeffrey',
#  'English',
#  'Bankruptcies',
#  'Murdoch',
#  'Applications',
#  'Operating',
#  'Corporation',
#  'Mattis',
#  'Donald',
#  'Lobbying',
#  'Sessions',
#  'Abortion',
#  'Marketing',
#  'Pence',
#  'Yellen',
#  'Military',
#  'Rangers',
#  'Tillerson',
#  'Horse',
#  'Warriors',
#  'Human',
#  'Malcolm',
#  'Bush',
#  'Professions',
#  'Forces',
#  'Doug',
#  'Teenagers',
#  'Upper',
#  'Hair',
#  'Vuitton',
#  '2016-',
#  'Child',
#  'Couture',
#  'Paleontology',
#  'Zealand',
#  'Italy',
#  'Missile',
#  'Hurricane',
#  'Communications',
#  'Nadal',
#  'Delivery',
#  'Disease',
#  'Native',
#  'Venture',
#  'Myanmar',
#  'Bicycles',
#  'Schools',
#  '21st',
#  'Insurance',
#  'Eavesdropping',
#  'Guggenheim',
#  'Doping',
#  'Bombs',
#  'Cartoons',
#  'Ford',
#  'E-Mail',
#  'Catalonia',
#  'Portugal',
#  'Wimbledon',
#  'Cuomo',
#  'Governors',
#  'Trudeau',
#  'Taliban',
#  'Tests',
#  'Segregation',
#  'Finance',
#  'Worth',
#  'Equity',
#  'Netherlands',
#  'Nicolas',
#  'Manhattan',
#  'Nazi',
#  'Florida',
#  'Brazil',
#  'Issues',
#  'K-12',
#  'Arena',
#  'Resources',
#  'Enforcement',
#  'Revenue',
#  'Mexico',
#  'Prisoners',
#  'Illegal',
#  'Williams',
#  'Reality',
#  'Genetics',
#  'Groups',
#  'T',
#  'Classic',
#  'Girls',
#  'Saturday',
#  'Spain',
#  '1939-45',
#  'Hiring',
#  'Smoking',
#  'Leasing',
#  'Crossword',
#  'Organizations',
#  'Forestry',
#  'Power',
#  'People',
#  'Firefighters',
#  'Suu',
#  'Corporate',
#  'Centers',
#  'McCain',
#  'Housing',
#  'Desegregation',
#  'Silicon',
#  'Restoration',
#  'Pollution',
#  'Manners',
#  'Catholic',
#  'Courts',
#  'Records',
#  'Girardi',
#  'Dying',
#  'Treaty',
#  '1962-',
#  'Areas',
#  'Domestic',
#  'Ohio',
#  'Driverless',
#  'Former',
#  'Kong',
#  'Puzzles',
#  'Academy',
#  'Nigeria',
#  'Methods',
#  'Thefts',
#  'Nonprofit',
#  'YouTube.com',
#  'Area',
#  'Software',
#  'Firearms',
#  'Authority',
#  'Changes',
#  'Jong-un',
#  'Suicides',
#  'California',
#  'Mixed',
#  'Whistle-Blowers',
#  'Middle',
#  'Lower',
#  'Ice',
#  'Congressional',
#  'Ivanka',
#  'Super',
#  'Solomon',
#  'Evolution',
#  'Thomas',
#  'Documentary',
#  'Cold',
#  'Fatalities',
#  'Safety',
#  'Boards',
#  'Surgery',
#  'Navy',
#  'Wages',
#  'Layoffs',
#  'Therapy',
#  'Fitzgerald',
#  'Ga',
#  'Programs',
#  'May',
#  'Smuggling',
#  'Committee',
#  'Running',
#  'Walmart',
#  'City',
#  'Live',
#  'Church',
#  'Kaepernick',
#  'Sayfullo',
#  'Democratic',
#  'Chase',
#  'Athletics',
#  'Jimmy',
#  'Rikers',
#  'Displaced',
#  'Southeast',
#  'Environment',
#  'Argentina',
#  'Nursing',
#  'Instagram',
#  'Equifax',
#  'Start-ups',
#  'Show',
#  'Programming',
#  'Antiquities',
#  'Hybrid',
#  'Press',
#  'Deductions',
#  'Race',
#  'Estate',
#  'Turnbull',
#  'Lyndon',
#  'Doctors',
#  'Emmanuel',
#  'Comic',
#  'Co',
#  'Putin',
#  'Communist',
#  'Care',
#  'Weight',
#  'Fires',
#  'Mayors',
#  'Litigation',
#  'Harvey',
#  'Charles',
#  'Statements',
#  'Inaugurations',
#  'Kushner',
#  'Birds',
#  'Technologies',
#  'Dancing',
#  'Kickbacks',
#  'Design',
#  'Energy',
#  'H',
#  'Paddock',
#  'Celebrities',
#  'Daily',
#  'Missiles',
#  'Luxury',
#  'Mariano',
#  'Christians',
#  '2016',
#  'Franken',
#  'Construction',
#  'Volkswagen',
#  'League',
#  'Seas',
#  'R',
#  'Customer',
#  'Criminals',
#  'Shutdowns',
#  'Pennsylvania',
#  'Lodgings',
#  'Employees',
#  'Suicide',
#  'International',
#  'Hurricanes',
#  'Colleges',
#  'Student',
#  'Radio',
#  'Immigration',
#  'Trevor',
#  'Lincoln',
#  'Rex',
#  'Longevity',
#  'Commission',
#  'Airports',
#  'F',
#  'Urban',
#  'Beyonce',
#  'York',
#  '#MeToo',
#  'Diet',
#  'Carmelo',
#  'Naturalization',
#  'Global',
#  'Taxicabs',
#  'Saudi',
#  'Decorations',
#  'Investigation',
#  'Jets',
#  'Dodgers',
#  'Anthony',
#  'FIFA',
#  'TV',
#  'Writing',
#  'Movie',
#  'Evangelical',
#  'Angeles',
#  'LLC',
#  'Goldman',
#  'Neutrality',
#  'Fringe',
#  'Musk',
#  'Bisexuality',
#  'Comedy',
#  'Weinstein',
#  'High',
#  'Parliaments',
#  'Other',
#  'Day',
#  'Qaeda',
#  'Violence',
#  'Bakeries',
#  'Love',
#  'Jones',
#  'Competition',
#  'Boston',
#  'Service',
#  'Hispanic-Americans',
#  'Track',
#  'Computer',
#  'Explosives',
#  'Freedom',
#  'Impeachment',
#  'Neglect',
#  'Family',
#  'Sexual',
#  'Libraries',
#  'Brooklyn',
#  'Memorandums',
#  'Fla',
#  'Drones',
#  'Polls',
#  'Tayyip',
#  '1977-',
#  'Decisions',
#  'NCAA',
#  'Sleep',
#  'Border',
#  'Royal',
#  'Rights',
#  'Consulates',
#  'Billboard',
#  'Penguins',
#  'Solar',
#  'Singapore',
#  'Building',
#  'Dresses',
#  'United',
#  'Automobile',
#  'Supreme',
#  'Russia',
#  'Kenya',
#  'Nobel',
#  'San',
#  'from',
#  'Bonds',
#  'Rajoy',
#  'Comey',
#  'Tex',
#  'Lee',
#  'Tesla',
#  'Anthem',
#  'Rodham',
#  'Golden',
#  'Francisco',
#  'Midterm',
#  'Puerto',
#  'Janet',
#  'Furnishings',
#  'Mental',
#  'Bitcoin',
#  'Jersey',
#  'Dodd-Frank',
#  'Milan',
#  'Speech',
#  'Motor',
#  'American',
#  'Humor',
#  'Bronx',
#  'Recep',
#  'Conservative',
#  'Emergencies',
#  'Tropical',
#  'Qatar',
#  'Nuclear',
#  'Mueller',
#  'Vladimir',
#  'Coups',
#  'Secrets',
#  'Label',
#  'Welfare',
#  'Internal',
#  'Caribbean',
#  'Disorders',
#  'Voter',
#  'Uber',
#  "Alzheimer's",
#  'Yemen',
#  'Media',
#  'Forensic',
#  'Robert',
#  'Justice',
#  'Fattah',
#  'Free',
#  '2001-',
#  'Misinformation',
#  'Terrorism',
#  'Clinton',
#  'Video',
#  'Twenty',
#  'Cowboys',
#  'Credits',
#  'Acquired',
#  'Plants',
#  'Golf',
#  'Racing',
#  'Humanity',
#  'Reserve',
#  'Arms',
#  'Dallas',
#  'Netanyahu',
#  'E',
#  'Square',
#  'Water',
#  'Settlements',
#  'Ethnic',
#  'Major',
#  'Rafael',
#  'Nightclubs',
#  'Greece',
#  'Broadcasting',
#  'Americans',
#  'Series',
#  'Cocktails',
#  'Andrew',
#  'Agency',
#  'World',
#  'Elections',
#  'de',
#  'Law',
#  'Atlantic',
#  'Gasoline',
#  'Bombing',
#  'Netflix',
#  'Pensions',
#  'Conservation',
#  'Disney',
#  'Team',
#  'Group',
#  'Workers',
#  'Species',
#  '1995-',
#  'Mets',
#  'Mobile',
#  'Cabs',
#  'Richard',
#  'Corporations',
#  'Berkeley',
#  'Seattle',
#  'Literature',
#  'Prosecutors',
#  'Poland',
#  'Crisis',
#  'Deficiency',
#  'Space',
#  'Flowers',
#  'Arabia',
#  'Shoes',
#  'Philharmonic',
#  'Christianity',
#  'Official',
#  'Hillary',
#  'Slavery',
#  'Muslims',
#  'Amendment',
#  'Pharmaceuticals',
#  'Architecture',
#  'Philippines',
#  'Publishing',
#  'Refugees',
#  'Greenwich',
#  'Government',
#  'Organized',
#  'Twitter',
#  'Today',
#  'Trapping',
#  'Libya',
#  'Monuments',
#  'Collections',
#  'Puigdemont',
#  'Arts',
#  'Side',
#  'Promotion',
#  'Porzingis',
#  'Springs',
#  'Islamic',
#  'Policies',
#  'Kyi',
#  'Violations',
#  'Times',
#  'Currency',
#  'Hunting',
#  'Shootings',
#  'Modern',
#  'Alabama',
#  'Lobbyists',
#  'Cooking',
#  'Jobs',
#  'Addiction',
#  'Livery',
#  'Exemptions',
#  '1958-',
#  'Aaron',
#  'Paul',
#  'Gorsuch',
#  'Regulation',
#  'Ethnicity',
#  'Champions',
#  'Tariff',
#  'Endangered',
#  'Shelters',
#  'Australian',
#  'Atlanta',
#  'Midtown',
#  'Independence',
#  'Flynn',
#  'Careers',
#  'Developing',
#  'The',
#  'Deferred',
#  'Melbourne',
#  'Jews',
#  'Poetry',
#  'Movements',
#  'Online',
#  'Aung',
#  'Emigration',
#  'Marlins',
#  'System',
#  'Assassinations',
#  'America',
#  'Defects',
#  'Nixon',
#  'Irma',
#  'US',
#  'Harlem',
#  'Mortgages',
#  'Queens',
#  'Attempted',
#  'Tax',
#  'Mosques',
#  'Mines',
#  'Cyberharassment',
#  'Oil',
#  'Emissions',
#  'Army',
#  'Rescues',
#  'Front',
#  'Houston',
#  'Animals',
#  'Contests',
#  'Network',
#  'Carolina',
#  'Joe',
#  'Baseball',
#  'Cavaliers',
#  'Africa',
#  'Md',
#  'Philadelphia',
#  'Advertising',
#  'Foreign',
#  'Campaign',
#  'Transportation',
#  'Buildings',
#  'Culture',
#  'Ballet',
#  'Kellyanne',
#  'Merkel',
#  'Marijuana',
#  'Hip-Hop',
#  'Defense',
#  'Manafort',
#  'Inflation',
#  'Coaches',
#  'Tony',
#  'Anthems',
#  'Travel',
#  'Pain-Relieving',
#  'Recordings',
#  "O'Reilly",
#  'Michael',
#  'Bureau',
#  'Association',
#  'Grocery',
#  'Salaries',
#  'Protectionism',
#  'Knowles',
#  'EU',
#  'Countries',
#  'China',
#  'Shopping',
#  'Ailes',
#  'Flake',
#  'McConnell',
#  'Jared',
#  'Homeless',
#  'Cellular',
#  "O'Brien",
#  'Rifle',
#  'Failures',
#  'Amtrak',
#  'Salman',
#  'Sectarian',
#  'Customs',
#  'Somalia',
#  'Colin',
#  'Berlin',
#  'Sachs',
#  'Languages',
#  'Phil',
#  'Control',
#  'La',
#  'Civil',
#  'Islam',
#  'Job',
#  'Obama',
#  'London',
#  'Industry',
#  'Life',
#  'Migrant',
#  'Psychologists',
#  'Jackson',
#  'by',
#  'Private',
#  'NYC',
#  'Moscow',
#  'Surveillance',
#  'E-Commerce',
#  'Hedge',
#  'Marine',
#  'Budget',
#  'Alternative',
#  'Opinion',
#  'Relocation',
#  'Syria',
#  'Knicks',
#  'October',
#  'Yorker',
#  'National',
#  'Home',
#  'West',
#  'Hassan',
#  'Parenting',
#  'Disabilities',
#  'Executives',
#  'Evacuees',
#  'Bernard',
#  'Infrastructure',
#  'Bezos',
#  'Accidents',
#  'Maduro',
#  'Barcelona',
#  'Interest',
#  'Professional',
#  'Rico',
#  'Assn',
#  'Crimes',
#  'Box',
#  'Against',
#  'Jinping',
#  'Chelsea',
#  'Anxiety',
#  'Transit',
#  'Kurds',
#  'Channel',
#  'Coal',
#  'Embassies',
#  'Streaming',
#  'Concussions',
#  'Evacuations',
#  'Tonight',
#  'Drug',
#  'Use',
#  'Change',
#  'Detroit',
#  'Seashores',
#  'Classified',
#  'Presidents',
#  'Travis',
#  'Parenthood',
#  'Structures',
#  'Unemployment',
#  'Amazon.com',
#  'Attack',
#  'Johnson',
#  'Movies',
#  'Embargoes',
#  'Presidency',
#  'Taxes',
#  'Innovation',
#  'Workplace',
#  'Reductions',
#  'Librarians',
#  'Nutrition',
#  'Spicer',
#  'School',
#  'Arrivals',
#  'DeVos',
#  'Local',
#  'Tennis',
#  'Special',
#  'Sweden',
#  'Barriers',
#  'Convictions',
#  'Banking',
#  'Milhous',
#  'Ethics',
#  'Jr',
#  'Games',
#  'Zimbabwe',
#  'Earthquakes',
#  '1992-',
#  'Politics',
#  'Cancer',
#  'Veterans',
#  'Business',
#  'Eclipses',
#  'Depression',
#  'Admissions',
#  '1953-2017',
#  'Pruitt',
#  'Game',
#  'Medicaid',
#  'Bars',
#  'Central',
#  'McMaster',
#  'Attorneys',
#  'Globes',
#  'Requirements',
#  'Strips',
#  'Appointments',
#  'Espionage',
#  'Council',
#  'Real',
#  'Voters',
#  'Facebook',
#  'Philanthropy',
#  'Hall',
#  'Breitbart',
#  'Basketball',
#  'Gary',
#  'Pets',
#  'Skin',
#  'Convention',
#  'Hostages',
#  'Jazz',
#  'Turkey',
#  'M',
#  'New',
#  'Gangs',
#  'Services',
#  'Indigenous',
#  'Holocaust',
#  'Opera',
#  '1985-',
#  'Floods',
#  'Photography',
#  'Field',
#  'Cup',
#  'Capital',
#  'Hazards',
#  'Baines',
#  'Football',
#  'Materials',
#  'Republic',
#  'Administration',
#  'Arenas',
#  'Management',
#  'Discrimination',
#  'Automobiles',
#  'Interior',
#  'Trans-Pacific',
#  'Sox',
#  'Transsexuals',
#  'Psychology',
#  'Homicides',
#  'Bank',
#  'SA',
#  'Magazines',
#  'Products',
#  'Blackouts',
#  'bin',
#  'L',
#  'Taxation',
#  'Al',
#  'Social',
#  'Serena',
#  'Shooting',
#  'Rehabilitation',
#  'Windows',
#  'Framework',
#  'Book',
#  'Elizabeth',
#  'Humanitarian',
#  'Christian',
#  'Price',
#  'Honors',
#  'Chicago',
#  'Balenciaga',
#  'Hate',
#  'Railroads',
#  'for',
#  'Extinct',
#  'Performing',
#  'False',
#  'Patriots',
#  'Stocks',
#  'Deaths',
#  'Economics',
#  'Duterte',
#  'Health',
#  'Sports',
#  'Malaysia',
#  'Abe',
#  'Cartoonists',
#  '11',
#  'College',
#  'Baltimore',
#  'Narendra',
#  'Conway',
#  'Shareholder',
#  'Pacific',
#  'France',
#  'Emotion',
#  '1861-65',
#  'Offerings',
#  'Speeches',
#  'Senate',
#  'Stress',
#  'Afghanistan',
#  'Noah',
#  'Station',
#  'Sydney',
#  'Cleveland',
#  '2018',
#  'Bashar',
#  'Cyberattacks',
#  'Traffic',
#  'Medicare',
#  'Park',
#  'Presidential',
#  'Homosexuality',
#  'Gucci',
#  'Debt',
#  'Vehicles',
#  'Citizenship',
#  'Roman',
#  'Elon',
#  'Homeland',
#  'al-',
#  'D',
#  'Night',
#  'French',
#  'Disasters',
#  'Cookbooks',
#  'Tunnels',
#  'Detention',
#  'Conditions',
#  "Christie's",
#  'Security',
#  'Baked',
#  'Furniture',
#  'Fargo',
#  'Prisons',
#  'Liberties',
#  'Egypt',
#  'Corker',
#  'Europe',
#  'Gardening',
#  'Pen',
#  'Immunization',
#  'University',
#  'Astronomy',
#  'Light',
#  'England',
#  'Slope',
#  'Palestinians',
#  'Semiautonomous',
#  'Marriage',
#  'Hotels',
#  'Death',
#  'Boys',
#  'Gun',
#  'Island',
#  'Vacations',
#  'Drugs',
#  'Diabetes',
#  'Christopher',
#  'B',
#  'Missing',
#  'Bicycling',
#  'Mugabe',
#  'Medical',
#  'Works',
#  'Red',
#  'Maritime',
#  'Asylum',
#  'Falcons',
#  'Injuries',
#  'Deregulation',
#  'Mark',
#  'Russian',
#  'Nev',
#  'Cosby',
#  'Mohammed',
#  'Weapons',
#  'Prizes',
#  'Drivers',
#  'Brutality',
#  'Artificial',
#  'Financial',
#  'Protection',
#  'Stephen',
#  'Ill',
#  'Cats',
#  'Fares',
#  'Historic',
#  'Jewels',
#  'Institutions',
#  'Hazardous',
#  'Louis',
#  'Planning',
#  'Pa',
#  'Miami',
#  'P',
#  'Magazine',
#  'Iraq',
#  'Fees',
#  'Deportation',
#  'Abdel',
#  'Telephones',
#  'Delays',
#  'Visas',
#  'Science',
#  'Actresses',
#  '1954-',
#  '1914-18',
#  'Harassment',
#  'Era',
#  'Maine',
#  'Warming',
#  'Alphabet',
#  'Whites',
#  'Awards',
#  'Mergers',
#  'Petroleum',
#  'Families',
#  'Taxicab',
#  'Institutional',
#  'Animal',
#  ...}
