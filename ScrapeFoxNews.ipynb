# %%
import requests
from bs4 import BeautifulSoup
import urllib

stories = []

def getTheGoodStuff(newsstories):
    global stories
    for data in newsstories:
        htmlatag = data.find("h2", class_="title").find("a")
        headline = htmlatag.getText()
        url = htmlatag.get("href")
        d = {"headline" : headline,
             "url" : url}
        stories.append(d)

def scrapeWebsites():
    global stories
    
    # Getting stories from Fox News.
    foxnews = "http://www.foxnews.com/"
    # page = urllib.urlopen(foxnews)
    r  = requests.get(foxnews)
    data = r.text
    soup = BeautifulSoup(data,"lxml")
    for i in range(0, 15):
        foundstories = soup.find_all("article", class_="article story-" + str(i))
        getTheGoodStuff(foundstories)
    
def displayStories():
    global stories
    for i in range(0, len(stories)):
        print(stories[i]["headline"])
        print(stories[i]['url'])
        print("")
    
scrapeWebsites()
displayStories()
# Out:
# Your AM business brief: Red Lobster bans plastic straws; Kroger, Walgreens team up
# https://video.foxbusiness.com/v/5843773846001/?#sp=show-clips
#
# Cory Booker calls for ditching SCOTUS nominee Kavanaugh whether he's ‘innocent or guilty’
# https://www.foxnews.com/politics/cory-booker-ditch-kavanaugh-whether-hes-innocent-or-guilty
#
# Your AM business brief: Red Lobster bans plastic straws; Kroger, Walgreens team up
# https://video.foxbusiness.com/v/5843773846001/?#sp=show-clips
#
# Packages sent to Pentagon that tested positive for ricin are suspected to have been mailed by a former Navy sailor, officials say
# https://www.foxnews.com/us/packages-sent-to-pentagon-that-tested-positive-for-ricin-are-suspected-to-have-been-mailed-by-a-former-navy-sailor-officials-say
#
# Elementary school teacher disappears without a trace
# https://www.foxnews.com/us/maine-school-teacher-disappears-without-a-trace
#
# Chicago officer testifies in Laquan McDonald murder trial
# https://video.foxnews.com/v/5843803969001/
#
# CHARLIE KIRK: 10 things Dems will take away if they win House and Senate
# https://www.foxnews.com/opinion/10-things-democrats-will-take-away-from-us-if-they-win-control-of-the-house-and-senate
#
# Chicago officer testifies in Laquan McDonald murder trial
# https://video.foxnews.com/v/5843803969001/
#
# Princess Di's biggest royal enemy wasn't who you think, shocking tell-all claims
# https://www.foxnews.com/entertainment/queen-elizabeths-rebel-sister-princess-margaret-never-forgave-princess-diana-for-shocking-tell-all-book-claims
#
# City moves closer to getting NHL expansion team following league meeting
# https://www.foxnews.com/sports/seattle-closer-to-getting-nhl-expansion-team-following-meeting-at-league-headquarters
#
# 'Tone deaf' Hillary wants to distract voters: Tomi Lahren
# https://video.foxnews.com/v/5843733387001/
#
# Grassley wants answers after Ford ex contradicts her polygraph prep claim
# https://www.foxnews.com/politics/christine-blasey-ford-ex-boyfriend-says-she-helped-friend-prep-for-potential-polygraph-grassley-sounds-alarm
#
# 'Tone deaf' Hillary wants to distract voters: Tomi Lahren
# https://video.foxnews.com/v/5843733387001/
#
# Ted Koppel mocks CNN star, claims network's ratings would be 'in the toilet without Donald Trump'
# https://www.foxnews.com/entertainment/ted-koppel-mocks-brian-stelter-cnns-ratings-would-be-in-the-toilet-without-donald-trump
#
# Masked gunman targeting victims in Chicago neighborhood, 2 men killed over 2 days: cops
# https://www.foxnews.com/us/masked-gunman-targeting-victims-in-chicago-neighborhood-2-men-killed-over-2-days-police-say
#
# Are Dems laying a perjury trap for Judge Kavanaugh?
# https://video.foxnews.com/v/5843600251001/
#
# Photos reveal just how close Chinese destroyer came to US ship
# https://www.foxnews.com/world/chinese-destroyers-unsafe-interaction-with-uss-decatur-in-south-china-sea-seen-in-stunning-photos
#
# Are Dems laying a perjury trap for Judge Kavanaugh?
# https://video.foxnews.com/v/5843600251001/
#
# Melania Trump visits former slave facility on Africa trip
# https://www.foxnews.com/politics/melania-trump-visits-former-slave-facility-on-africa-trip-i-will-never-forget-the-stories
#
# 10 'poor man's habits' for saving a buck
# https://www.foxbusiness.com/personal-finance/10-poor-mans-habits-for-saving-a-buck
#
# Cotton: Democrats will stop at nothing to defeat Kavanaugh
# https://video.foxnews.com/v/5843596797001/
#
# WILD PICS: Rowdy 'burlesque' dancers hijack cruise, prompting Royal refund
# https://www.foxnews.com/travel/royal-caribbean-refunds-passengers-shocked-by-conferences-crazy-burlesque-cruise
#
# Cotton: Democrats will stop at nothing to defeat Kavanaugh
# https://video.foxnews.com/v/5843596797001/
#
#
# Casey Anthony 'open' to having more children, 'doesn't care' what people think, report says
# https://www.foxnews.com/us/casey-anthony-open-to-having-more-children-doesnt-care-what-people-think-report-says
#
# CBS fires showrunner for hit show after misconduct investigation
# https://www.foxnews.com/entertainment/cbs-fires-ncis-new-orleans-showrunner-brad-kern-after-misconduct-investigation
#
# The 'Kavanaugh bump' is real: Sen. Lindsey Graham
# http://video.foxnews.com/v/5843576867001/
#
#
# The 'Kavanaugh bump' is real: Sen. Lindsey Graham
# http://video.foxnews.com/v/5843576867001/
#
# Here's what time to expect first-ever 'presidential alert' on your mobile device
# https://www.foxnews.com/us/fema-test-of-presidential-alert-to-go-out-wednesday-to-225-million-electronic-devices
#
# TOUCHING PIC: NFL fan helps disabled backer of rival team stand for anthem
# https://www.foxnews.com/us/saints-fan-helps-disabled-giants-fan-stand-for-national-anthem-in-viral-photo
#
# Sean Spicer says Hillary Clinton still doesn't get it
# https://video.foxnews.com/v/5843756718001/
#
# Sean Spicer says Hillary Clinton still doesn't get it
# https://video.foxnews.com/v/5843756718001/
#
# Passenger's mile-high workout gets flight diverted, man claims
# https://www.foxnews.com/travel/american-airlines-flight-diverted-after-passenger-refused-to-stop-doing-pull-ups-on-plane-man-claims
#
# Secret identity of 150-year-old body found in NYC revealed
# https://www.foxnews.com/science/secret-identity-of-150-year-old-body-found-in-nyc-revealed
#
# Mom, 53, found dead one week after disappearing while on a hike with her daughter
# https://www.foxnews.com/us/body-of-missing-woman-hiking-in-great-smoky-mountains-national-park-found
#
# Trump reaped millions in shady tax schemes from father's business, report says; NY Tax Department 'reviewing' allegations
# https://www.foxnews.com/politics/trump-reaped-millions-in-shady-tax-schemes-from-fathers-business-report-says-ny-tax-department-reviewing-allegations
#
#
# 'DWTS' contestant John Schneider reveals huge cost of ‘80s hit 'Dukes'
# https://www.foxnews.com/entertainment/dwts-dukes-of-hazzard-star-john-schneider-reveals-whopping-cost-of-down-home-show
#
# WATCH: GOP senator pushes back when confronted by anti-Kavanaugh protester
# http://insider.foxnews.com/2018/10/03/gop-sen-bill-cassidy-pushes-back-when-confronted-anti-brett-kavanaugh-protester
#
# Auto racing exec accused of peeping into neighbor's daughter's room: report
# https://www.foxnews.com/us/atlanta-motor-speedway-exec-accused-of-peeping-into-neighbors-daughters-room-police
